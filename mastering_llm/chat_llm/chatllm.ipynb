# %%
print("Hello")
# Out:
# Hello

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')

if not api_key:
    print("API key not found. Please set the GEMINI_API_KEY environment variable.")
else:
    print("API key loaded successfully.")
# Out:
# API key loaded successfully.

# %%
import requests

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}
data = {
    "model": "gemini-2.5-flash",
    "messages": [
        {"role": "user", "content": "Hello, how are you?"}
    ]
}

# %%
response = requests.post(
    "https://generativelanguage.googleapis.com/v1beta/openai/chat/completions", 
    headers=headers, 
    json=data
) 

response.json()
# Out:
# {'choices': [{'finish_reason': 'stop',
#    'index': 0,
#    'message': {'content': "Hello! I'm doing well, thank you for asking.\n\nHow about you? I hope you're having a good day!",
#     'role': 'assistant'}}],
#  'created': 1764155611,
#  'id': '2-AmaZD-K-2x4-EPtKXroQ8',
#  'model': 'gemini-2.5-flash',
#  'object': 'chat.completion',
#  'usage': {'completion_tokens': 28, 'prompt_tokens': 7, 'total_tokens': 80}}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# "Hello! I'm doing well, thank you for asking.\n\nHow about you? I hope you're having a good day!"
